# %% [markdown]
# # Project: COVID-19 World Vaccination Progress
#
# Submitted By: -
# Prakash Mohan Tarai(EBEON0123702262)

# %% [markdown]
# ![A%20global%20database%20of%20COVID-19%20vaccinations%20img.png](attachment:A%20global%20database%20of%20COVID-19%20vaccinations%20img.png)

# %% [markdown]
# # Abstract
# Data is collected daily from Our World in Data GitHub repository for covid-19, merged and uploaded. Country level vaccination data is gathered and assembled in one single file. Then, this data file is merged with locations data file to include vaccination sources information. A second file, with manufacturers information, is included.

# %% [markdown]
# # Contents
# The data (country vaccinations) contains the following information:
#
# * Country- this is the country for which the vaccination information is provided;
# * Country ISO Code - ISO code for the country;
# * Date - date for the data entry; for some of the dates we have only the daily vaccinations, for others, only the (cumulative) total;
# * Total number of vaccinations - this is the absolute number of total immunizations in the country;
# * Total number of people vaccinated - a person, depending on the immunization scheme, will receive one or more (typically 2) vaccines; at a certain moment, the number of vaccination might be larger than the number of people;
# * Total number of people fully vaccinated - this is the number of people that received the entire set of immunization according to the immunization scheme (typically 2); at a certain moment in time, there might be a certain number of people that received one vaccine and another number (smaller) of people that received all vaccines in the scheme;
# * Daily vaccinations (raw) - for a certain data entry, the number of vaccination for that date/country;
# * Daily vaccinations - for a certain data entry, the number of vaccination for that date/country;
# * Total vaccinations per hundred - ratio (in percent) between vaccination number and total population up to the date in the country;
# * Total number of people vaccinated per hundred - ratio (in percent) between population immunized and total population up to the date in the country;
# * Total number of people fully vaccinated per hundred - ratio (in percent) between population fully immunized and total population up to the date in the country;
# * Number of vaccinations per day - number of daily vaccination for that day and country;
# * Daily vaccinations per million - ratio (in ppm) between vaccination number and total population for the current date in the country;
# * Vaccines used in the country - total number of vaccines used in the country (up to date);
# * Source name - source of the information (national authority, international organization, local organization etc.);
# * Source website - website of the source of information;
#
# There is a second file added recently (country vaccinations by manufacturer), with the following columns:
#
# * Location - country;
# * Date - date;
# * Vaccine - vaccine type;
# * Total number of vaccinations - total number of vaccinations / current time and vaccine type.

# %% [markdown]
# # Inspiration
# Track COVID-19 vaccination in the World, answer instantly to your questions:
#
# * Which country is using what vaccine?
# * In which country the vaccination programme is more advanced?
# * Where are vaccinated more people per day? But in terms of percent from entire population ?
#  Combine this dataset with COVID-19 World Testing Progress and COVID-19 Variants Worldwide Evolution to get more insights on the dynamics of the pandemics, as reflected in the interdependence of amount of testing performed, results of sequencing and vaccination campaigns.

# %% [markdown]
# #  INTRODUCTION:
#
# The COVID-19 pandemic has presented an unprecedented global health challenge, affecting millions of people worldwide. As nations strive to combat the spread of the virus, vaccination programs have emerged as a crucial tool in controlling the pandemic and mitigating its impact. This study focuses on analyzing the world's COVID-19 vaccination progress, aiming to provide insights into the global efforts to vaccinate populations and track the effectiveness of immunization campaigns.
#
# The introduction of COVID-19 vaccines has brought hope for a way out of the crisis. Governments, healthcare organizations, and pharmaceutical companies have collaborated tirelessly to develop and distribute vaccines on an unparalleled scale. Monitoring and understanding the progress of vaccination campaigns is vital for evaluating their success, identifying disparities, and informing future strategies.
#
# This study aims to examine the world's vaccination progress by analyzing comprehensive datasets that encompass various countries and regions. By exploring the data, we can gain valuable insights into the number of total vaccinations administered, people vaccinated, and people fully vaccinated over time. Additionally, we can investigate the daily vaccination rates, vaccination coverage, and regional disparities in immunization efforts.
#
# Understanding the world's COVID-19 vaccination progress offers several benefits. It enables policymakers to assess the effectiveness of vaccination strategies and make informed decisions regarding resource allocation, distribution priorities, and public health measures. It also provides researchers and public health experts with valuable data to evaluate the impact of vaccination on reducing infection rates, hospitalizations, and mortality.
#
# Through this analysis, we seek to contribute to the growing body of knowledge surrounding COVID-19 vaccinations and their global impact. By examining vaccination trends and identifying areas of success or concern, we can offer insights to guide future immunization campaigns, enhance equitable vaccine distribution, and support global health efforts in combating the COVID-19 pandemic.
#
# Overall, this study aims to shed light on the world's COVID-19 vaccination progress, providing a comprehensive understanding of the achievements, challenges, and opportunities in the global fight against the pandemic. By analyzing the data, we strive to contribute to evidence-based decision-making, ultimately working towards a safer and healthier world for all.

# %% [markdown]
# ###  AIM
#
# The aim of this study is to analyze the global COVID-19 vaccination progress and its implications. Specifically, the study seeks to achieve the following objectives:
#
# Assess the overall progress of COVID-19 vaccination campaigns worldwide: This includes analyzing the cumulative number of vaccinations administered, tracking the number of people vaccinated, and monitoring the percentage of the population that has received at least one dose or is fully vaccinated.
#
# Examine the temporal trends and patterns in vaccination rates: By analyzing the daily vaccination rates, the study aims to identify any fluctuations, spikes, or declining trends over time. This analysis can help understand the effectiveness of vaccination programs, identify potential barriers or challenges, and highlight regions or countries with notable vaccination achievements.
#
# Evaluate regional disparities in vaccination coverage: The study aims to identify variations in vaccination rates across different countries, continents, or regions. By comparing the progress made in different parts of the world, the analysis can uncover potential factors contributing to variations in vaccination coverage, such as socioeconomic factors, healthcare infrastructure, or vaccine availability.
#
# Explore the relationship between vaccination progress and COVID-19 indicators: The study aims to investigate the correlation between vaccination rates and key COVID-19 indicators, such as infection rates, hospitalizations, and mortality. Understanding this relationship can provide insights into the impact of vaccination on reducing the burden of the disease and potentially guide future public health interventions.
#
# Identify challenges and opportunities in global vaccination efforts: By examining the data, the study aims to identify any challenges or barriers that hinder vaccination progress, such as vaccine hesitancy, supply chain issues, or inequitable distribution. Additionally, the analysis can uncover success stories and best practices in vaccination campaigns, offering opportunities for knowledge-sharing and improvement of global immunization strategies.
#
# By achieving these objectives, the study aims to contribute to the understanding of the world's COVID-19 vaccination progress, providing valuable insights for policymakers, public health experts, and researchers. The findings can inform evidence-based decision-making, support equitable vaccine distribution efforts, and guide future interventions to combat the pandemic effectively.

# %% [markdown]
# ### Tools
# - Numpy
# - pandas
# - Matplotlib
# - Seaborn
# - Scikit learn

# %% [markdown]
# ### Project overview
# - import libraries
# - Read the csv file
# - Data cleaning
# - Data visualization
# - Creation of Model
# - Conclusion

# %% [markdown]
# # Dataset source -
# ### Kaggle: - https://www.kaggle.com/datasets/gpreda/covid-world-vaccination-progress

# %% [markdown]
# ### Loading libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.svm import SVR
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Read the csv file

# %%
df = pd.read_csv("country_vaccinations.csv")

# %%
df
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 86507     Zimbabwe      ZWE  2022-03-25           8691642.0
# 86508     Zimbabwe      ZWE  2022-03-26           8791728.0
# 86509     Zimbabwe      ZWE  2022-03-27           8845039.0
# 86510     Zimbabwe      ZWE  2022-03-28           8934360.0
# 86511     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# ...

# %% [markdown]
# ### Find out how many rows and columns present in the dataset

# %%
df.shape
# Out:
# (86512, 15)

# %%
df.tail()
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 86507  Zimbabwe      ZWE  2022-03-25           8691642.0          4814582.0
# 86508  Zimbabwe      ZWE  2022-03-26           8791728.0          4886242.0
# 86509  Zimbabwe      ZWE  2022-03-27           8845039.0          4918147.0
# 86510  Zimbabwe      ZWE  2022-03-28           8934360.0          4975433.0
# 86511  Zimbabwe      ZWE  2022-03-29           9039729.0          5053114.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 86507                3473523.0                139213.0             69579.0
# 86508                3487962.0                100086.0             83429.0
# 86509                3493763.0                 53311.0             90629.0
# 86510                3501493.0                 89321.0            100614.0
# 86511                3510256.0                105369.0            103751.0
#
# ...

# %%
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86512 entries, 0 to 86511
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              86512 non-null  object
#  1   iso_code                             86512 non-null  object
#  2   date                                 86512 non-null  object
#  3   total_vaccinations                   43607 non-null  float64
#  4   people_vaccinated                    41294 non-null  float64
#  5   people_fully_vaccinated              38802 non-null  float64
#  6   daily_vaccinations_raw               35362 non-null  float64
#  7   daily_vaccinations                   86213 non-null  float64
#  8   total_vaccinations_per_hundred       43607 non-null  float64
#  9   people_vaccinated_per_hundred        41294 non-null  float64
#  10  people_fully_vaccinated_per_hundred  38802 non-null  float64
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = df.dropna(axis=0)

# %%
df = df.dropna(axis=1)

# %%
df = df.fillna(1)

# %%
df = df.fillna(df.mean())

# %%
df = df.fillna(df.median())

# %%
df = df.fillna(df.mode().iloc[0])

# %%
df = df.ffill()

# %%
df = df.bfill()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Showing all the columns headings in the datase

# %%
df.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %% [markdown]
# ### Showing all the features(columns) with its corresponding datatypes

# %%
df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %% [markdown]
# ### To check the Null Values for each column

# %%
df.isnull()
# Out:
#        country  iso_code   date  total_vaccinations  people_vaccinated  \
# 94       False     False  False               False              False
# 101      False     False  False               False              False
# 339      False     False  False               False              False
# 433      False     False  False               False              False
# 515      False     False  False               False              False
# ...        ...       ...    ...                 ...                ...
# 86507    False     False  False               False              False
# 86508    False     False  False               False              False
# 86509    False     False  False               False              False
# 86510    False     False  False               False              False
# 86511    False     False  False               False              False
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# ...

# %% [markdown]
# # the count of missing values in each column of the DataFrame.

# %%
df.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %% [markdown]
# # To display the number of unique values in each column of the DataFrame.

# %%
df.nunique()
# Out:
# country                                  169
# iso_code                                 169
# date                                     471
# total_vaccinations                     30516
# people_vaccinated                      30374
# people_fully_vaccinated                29894
# daily_vaccinations_raw                 25177
# daily_vaccinations                     25860
# total_vaccinations_per_hundred         15892
# people_vaccinated_per_hundred           8765
# people_fully_vaccinated_per_hundred     8364
# daily_vaccinations_per_million         10515
# vaccines                                  74
# source_name                               75
# source_website                           109
# dtype: int64

# %%
df.describe()     # summary of statistics
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.084700e+04       3.084700e+04             3.084700e+04
# mean         3.980375e+07       2.177533e+07             1.579596e+07
# std          1.451667e+08       8.053173e+07             5.898165e+07
# min          3.000000e+00       3.000000e+00             1.000000e+00
# 25%          1.153332e+06       7.339795e+05             3.704450e+05
# 50%          6.335305e+06       3.688092e+06             2.211035e+06
# 75%          2.520629e+07       1.440668e+07             9.121526e+06
# max          3.243599e+09       1.275541e+09             1.240777e+09
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.084700e+04        3.084700e+04
# mean             2.021875e+05        1.975297e+05
# std              7.041931e+05        6.400504e+05
# min              0.000000e+00        0.000000e+00
# 25%              5.498000e+03        7.329500e+03
# ...

# %% [markdown]
# ### to find the correlation

# %%
df.corr()
# Out:
#                                      total_vaccinations  people_vaccinated  \
# total_vaccinations                             1.000000           0.983371
# people_vaccinated                              0.983371           1.000000
# people_fully_vaccinated                        0.989133           0.957663
# daily_vaccinations_raw                         0.691492           0.759106
# daily_vaccinations                             0.762267           0.836367
# total_vaccinations_per_hundred                 0.147346           0.105780
# people_vaccinated_per_hundred                  0.174610           0.143675
# people_fully_vaccinated_per_hundred            0.138652           0.097362
# daily_vaccinations_per_million                -0.000360           0.007071
#
#                                      people_fully_vaccinated  \
# total_vaccinations                                  0.989133
# people_vaccinated                                   0.957663
# ...

# %% [markdown]
# ## VISUALIZATION

# %% [markdown]
# # heat map

# %%
numeric_cols = ['total_vaccinations', 'people_vaccinated', 'people_fully_vaccinated', 'daily_vaccinations']
corr_matrix = df[numeric_cols].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Bar plot

# %%
plt.figure(figsize=(30, 10))
sns.barplot(data=df, x='country', y='total_vaccinations')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Total Vaccinations')
plt.title('Total Vaccinations by Country')
plt.show()

# %% [markdown]
# # Line plot

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='date', y='total_vaccinations', hue='country')
plt.xticks(rotation=45)
plt.xlabel('Date')
plt.ylabel('Total Vaccinations')
plt.title('Total Vaccinations over Time')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Scatter plot of total vaccinations vs. people fully vaccinated

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='total_vaccinations', y='people_fully_vaccinated', hue='country')
plt.xlabel('Total Vaccinations')
plt.ylabel('People Fully Vaccinated')
plt.title('Total Vaccinations vs. People Fully Vaccinated')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Box plot

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='vaccines', y='daily_vaccinations')
plt.xticks(rotation=90)
plt.xlabel('Vaccine')
plt.ylabel('Daily Vaccinations')
plt.title('Daily Vaccinations by Vaccine Type')
plt.show()

# %% [markdown]
# # dish plot

# %%
# Create a distplot for the 'daily_vaccinations' column
plt.figure(figsize=(10, 8))
sns.distplot(df['daily_vaccinations'], bins=20)
plt.title('Daily Vaccinations by Vaccine Type', fontsize=15)
plt.xlabel('Daily Vaccinations', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.show()

# %% [markdown]
# # pie chart

# %% [markdown]
# #(plt.figure(figsize=(8, 8))
# plt.pie(df['country'].value_counts(), labels=['Zimbabwe', 'Afghanistan'], autopct='%0.2f%%')
# plt.title("Pie Chart Distribution", fontsize=14)
# plt.legend()
# plt.show())

# %% [markdown]
# # train data and test data

# %%
x = df[['total_vaccinations',]]
y = df['daily_vaccinations']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (24677, 1)
# (6170, 1)
# (24677,)
# (6170,)

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# Linear Regression is a supervised learning algorithm that establishes a linear relationship between input variables and a continuous target variable. It predicts the target variable's value based on the coefficients of the linear equation and making it suitable for simple regression tasks.

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train = x_train.dropna()
y_train = y_train.dropna()

# %%
lr = LinearRegression(normalize=False)
lr.fit(x_train, y_train)
# Out:
# LinearRegression(normalize=False)

# %%
lr_acc = lr.score(x_train,y_train)*100
print("Linear Regressor Accuracy -",lr_acc)
# Out:
# Linear Regressor Accuracy - 58.05953364202894

# %%
lr_acc = lr.score(x_test,y_test)*100
print("Linear Regressor Accuracy -",lr_acc)
# Out:
# Linear Regressor Accuracy - 58.271119460615274

# %%
y_pred = lr.predict(x_test)

# %%
print("MAE" ,metrics.mean_absolute_error(y_test, y_pred))
print("MSE" ,metrics.mean_squared_error(y_test, y_pred))
print("RMSE" , np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("R2" , metrics.explained_variance_score(y_test, y_pred))
# Out:
# MAE 150374.0585482154
# MSE 178303844232.19458
# RMSE 422260.3986075353
# R2 0.58273605577925

# %%
lr_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
lr_df
# Out:
#          Actual     Predicted
# 82637  717763.0  1.368639e+06
# 79198   32011.0  6.804541e+04
# 47472    1840.0  6.996165e+04
# 9516    21508.0  7.124366e+04
# 77399  846179.0  2.929352e+05
# ...         ...           ...
# 43269    9021.0  6.485697e+04
# 4219   261040.0  1.387354e+05
# 71211    5977.0  6.921211e+04
# 75402     231.0  6.365565e+04
# 13489   76345.0  7.256537e+04
#
# [6170 rows x 2 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(lr.predict(x_test[:200]), label="prediction", linewidth=2.0, color='blue')
plt.plot(y_test[:200].values, label="real_values", linewidth=2.0, color='red')
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### Random Forest Regressor Model

# %% [markdown]
# * Random Forest is a supervised learning algorithm. It falls under the category of supervised machine learning because it requires labeled training data, where the input features and their corresponding output labels are provided during the training phase. The algorithm learns from this labeled data to make predictions or classify new, unseen instances.
# * combines multiple decision trees to improve the accuracy of the predictions in supervised classification and regression tasks.

# %%
x = df[['total_vaccinations',]]
y = df['daily_vaccinations']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rf_acc_train = rf.score(x_train, y_train) * 100
print("Random Forest Regressor Accuracy (Training):", rf_acc_train)
# Out:
# Random Forest Regressor Accuracy (Training): 96.30189964540023

# %%
rf_acc_test = rf.score(x_test, y_test) * 100
print("Random Forest Regressor Accuracy (Testing):", rf_acc_test)
# Out:
# Random Forest Regressor Accuracy (Testing): 76.07758044201954

# %%
y_pred = rf.predict(x_test)

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = metrics.explained_variance_score(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 127140.80577777042
# MSE: 102218399233.05664
# RMSE: 319716.12288568844
# R2: 0.760839910557892

# %%
rf_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(rf_df)
# Out:
#          Actual      Predicted
# 82637  717763.0  747073.840000
# 79198   32011.0   18852.170000
# 47472    1840.0   25451.660000
# 9516    21508.0   28244.420000
# 77399  846179.0   60744.250000
# ...         ...            ...
# 43269    9021.0    6914.560000
# 4219   261040.0  167413.850000
# 71211    5977.0    6741.820000
# 75402     231.0      74.968738
# 13489   76345.0   21527.410000
#
# [6170 rows x 2 columns]

# %%
plt.figure(figsize=(20, 8))
plt.plot(rf.predict(x_test[:200]), label="Prediction", linewidth=2.0, color='blue')
plt.plot(y_test[:200].values, label="Real Values", linewidth=2.0, color='lightcoral')
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ### K Neighbors Regressor Model

# %% [markdown]
# K Neighbors Regressor is a supervised learning algorithm that predicts continuous numerical values based on the average of the values of its k nearest neighbors in the feature space, making it useful for regression tasks where nearby data points have similar outputs.

# %%
x = df[['total_vaccinations',]]
y = df['daily_vaccinations']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
knn = KNeighborsRegressor(n_neighbors=1, weights='uniform')
knn.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=1)

# %%
knn_acc_train = knn.score(x_train, y_train) * 100
print("K Neighbors Regressor Accuracy (Training):", knn_acc_train)
# Out:
# K Neighbors Regressor Accuracy (Training): 99.99884593065273

# %%
knn_acc_test = knn.score(x_test, y_test) * 100
print("K Neighbors Regressor Accuracy (Testing):", knn_acc_test)
# Out:
# K Neighbors Regressor Accuracy (Testing): 66.64385152093945

# %%
y_pred = knn.predict(x_test)

# %%
mae = metrics.mean_absolute_error(y_test, y_pred)
mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = metrics.explained_variance_score(y_test, y_pred)

# %%
print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 143516.56790923825
# MSE: 142527894966.72318
# RMSE: 377528.6677415679
# R2: 0.6664808486539906

# %%
knn_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(knn_df)
# Out:
#          Actual  Predicted
# 82637  717763.0   730210.0
# 79198   32011.0    21756.0
# 47472    1840.0    35445.0
# 9516    21508.0    39121.0
# 77399  846179.0    44784.0
# ...         ...        ...
# 43269    9021.0     2804.0
# 4219   261040.0   155301.0
# 71211    5977.0     5978.0
# 75402     231.0       88.0
# 13489   76345.0     6930.0
#
# [6170 rows x 2 columns]

# %%
plt.figure(figsize=(20, 8))
plt.plot(knn.predict(x_test[:200]), label="Prediction", linewidth=2.0, color='blue')
plt.plot(y_test[:200].values, label="Real Values", linewidth=2.0, color='lightcoral')
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Observation:

# %% [markdown]
# * Based on the accuracy scores,the Random Forest model is the best choice for predicting forecasting.The Random Forest model has a train accuray of 96.30% ana a test accuracy of 76.07% .This means that the model is able to accurately predict claims when it is trained on data and when it is tested on new data.
# * Overall,the Random Forest model is the best choice for predicting COVID-19 World Vaccination Progress Forecasting because it has heighest accuracy.

# %% [markdown]
# ## Comparing Models

# %%
acc = {'model': ['lr_acc', 'rf_acc_train', 'knn_acc_train'], 'accuracy': [lr_acc, rf_acc_test, knn_acc_test]}

# %%
acc_df = pd.DataFrame(acc)
acc_df
# Out:
#            model   accuracy
# 0         lr_acc  58.271119
# 1   rf_acc_train  76.077580
# 2  knn_acc_train  66.643852

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='model',y='accuracy',data=acc_df)
plt.show()

# %% [markdown]
# # Conclusions:
# * Vaccination progress: Analyze the total number of vaccinations, people vaccinated, and people fully vaccinated to determine the overall progress of vaccination campaigns in different countries.
# * Vaccination rates: Compare the number of vaccinations per day across countries to identify variations in vaccination rates and trends.
# * Regional differences: Explore differences in vaccination rates and coverage among different regions or continents to assess the effectiveness of vaccination strategies.
# * Time analysis: Examine the dataset over time to identify any significant changes or patterns in vaccination rates or coverage.
# * Identify outliers: Look for countries with unusually high or low vaccination rates to understand potential factors influencing their performance.
# * Correlation analysis: Investigate potential correlations between vaccination rates and other variables, such as GDP, population density, or healthcare infrastructure, to understand the factors influencing vaccination success.
